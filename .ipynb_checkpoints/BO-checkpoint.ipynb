# %%
# %load_ext autoreload
# %autoreload 2
% pylab inline

pylab.rcParams['figure.figsize'] = (15, 6)

import seaborn as sns

sns.set_style("darkgrid")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib
#  /Users/tmpethick/anaconda3/envs/eth/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning:pylab import has clobbered these variables: ['f', 'multivariate_normal']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
from src.bo import *
from src.dngo import *
from src.acquisition_functions import EI, UCB

def f(x):
    return np.sinc(x * 10 - 5).sum(axis=1)[:, None]

rng = np.random.RandomState(42)
x_train = rng.uniform(0, 1, 4)[:, None]
y_train = f(x_train)

################

nn = TFModel(input_dim=1, dim_basis=50, epochs=1000, batch_size=10)
reg = BayesianLinearRegression(num_mcmc=0, burn_in=1000, mcmc_steps=1000)
model = BOModel(nn, regressor=reg)
model.init(x_train, y_train)

x = (np.linspace(0, 1, 100))[:,None]
y = f(x)
model.plot_prediction(x,y)
# Out:
# Optimization terminated successfully.
#          Current function value: 147.353317
#          Iterations: 76
#          Function evaluations: 173

# %% [raw]
# acq = EI(model, par=0.01)
# acq = UCB(model)
# bo = BO(f, model, acquisition_function=acq, n_iter=20, bounds=np.array([[0,1]]))
# bo.run()

# %%
from hpolib.benchmarks.synthetic_functions import Branin

from src.bo import random_hypercube_samples, vectorize

f = Branin()
info = f.get_meta_information()
bounds = np.array(info['bounds'])
f = vectorize(f)

# %%
# Random sample
samples = random_hypercube_samples(100, bounds)
values = f(samples)
values[np.argmax(values)]
# Out:
# array([ 202.62384425])

# %%
input_dim = bounds.shape[0]
nn = TFModel(input_dim=input_dim, dim_basis=50, epochs=1000, batch_size=10)
reg = BayesianLinearRegression(num_mcmc=0, burn_in=1000, mcmc_steps=1000)
model = BOModel(nn, regressor=reg)
acq = EI(model, par=0.01)
# acq = UCB(model)
bo = BO(f, model, acquisition_function=acq, n_iter=20, bounds=bounds)
bo.run()
bo.model.get_incumbent()
# Out:
#  /Users/tmpethick/GoogleDrive/dtu/8-5-ETH-summer/eth-project/src/priors.py:24: RuntimeWarning:divide by zero encountered in log
#  /Users/tmpethick/anaconda3/envs/eth/lib/python3.6/site-packages/scipy/optimize/optimize.py:563: RuntimeWarning:invalid value encountered in subtract
# Warning: Maximum number of function evaluations has been exceeded.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-05ace8e594e6> in <module>()
#       6 # acq = UCB(model)
#       7 bo = BO(f, model, acquisition_function=acq, n_iter=20, bounds=bounds)
# ----> 8 bo.run()
#       9 bo.model.get_incumbent()
#
# ~/GoogleDrive/dtu/8-5-ETH-summer/eth-project/src/bo.py in run(self, n_kickstart, do_plot)
#     104
#     105             if do_plot:
# --> 106                 self.plot_prediction(x_new=x_new)
#     107
#     108             self.model.add_observations(X_new, Y_new)
#
# ~/GoogleDrive/dtu/8-5-ETH-summer/eth-project/src/bo.py in plot_prediction(self, x_new)
#      75
#      76             flattenxinput = np.reshape(xinput, -1, dims)
# ---> 77             y = self.model.acq(flattenxinput, self.acquisition_function.calc)
#      78             y= np.reshape(y, xinput.shape[:-1])
#      79
#
# ~/GoogleDrive/dtu/8-5-ETH-summer/eth-project/src/dngo.py in acq(self, X, acq)
#      63         """
#      64
# ---> 65         D = self.nn_model.predict_basis(self.sess, X)
#      66         sample_predictions = self.gp.predict_all(D)
#      67
#
# ~/GoogleDrive/dtu/8-5-ETH-summer/eth-project/src/neural_network.py in predict_basis(self, sess, x)
#     110     def predict_basis(self, sess, x):
#     111         if self.normalize_input:
# --> 112             x, _, _ = zero_mean_unit_var_normalization(x, mean=self.X_mean, std=self.X_std)
#     113
#     114         return sess.run(self.basis, {self.x: x})
#
# ~/GoogleDrive/dtu/8-5-ETH-summer/eth-project/src/neural_network.py in zero_mean_unit_var_normalization(X, mean, std)
#      19         std = np.std(X, axis=0)
#      20
# ---> 21     X_normalized = (X - mean) / std
#      22
#      23     return X_normalized, mean, std
#
# ValueError: operands could not be broadcast together with shapes (20000,) (2,)

# %%
bo.plot_prediction()
